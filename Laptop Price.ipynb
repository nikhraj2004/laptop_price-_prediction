# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# UnicodeDecodeError: 'utf-8' codec can't decode

# %%
df=pd.read_csv("/content/drive/MyDrive/CGU_AI & DS/database/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample(3)
# Out:
#     Company             Product  TypeName  Inches       ScreenResolution  \
# 808    Dell       Inspiron 7567    Gaming    15.6  4K Ultra HD 3840x2160
# 675     MSI           GP62 7RDX    Gaming    15.6      Full HD 1920x1080
# 279  Lenovo  IdeaPad 320-17IKBR  Notebook    17.3      Full HD 1920x1080
#
#                              Cpu   Ram                Memory  \
# 808  Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 675  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 279   Intel Core i7 8550U 1.8GHz   8GB               2TB HDD
#
#                             Gpu       OpSys  Weight  Price_euros
# 808  Nvidia GeForce GTX 1050 Ti  Windows 10  2.62kg       1679.0
# 675     Nvidia GeForce GTX 1050  Windows 10   2.4kg       1294.0
# 279        Nvidia GeForce MX150       No OS   2.8kg        849.0

# %%
print(df.isnull().sum())
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df.drop_duplicates(inplace=True)

# %%
df.sample()
# Out:
#     Company Product   TypeName  Inches  \
# 510    Dell  XPS 13  Ultrabook    13.3
#
#                               ScreenResolution                         Cpu  \
# 510  IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 7200U 2.5GHz
#
#      Ram     Memory                    Gpu       OpSys  Weight  Price_euros
# 510  8GB  128GB SSD  Intel HD Graphics 620  Windows 10  1.29kg        899.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 129.5+ KB

# %%
# Data Processing/Cleaning/EDA
# EDA: Exploratory Data Analysis
# Univariate Analysis
# Bivariate Analysis

# %%
df['Price']=round(df['Price_euros']*95.72).astype('int')

# %%
df.sample(2)
# Out:
#        Company         Product   TypeName  Inches       ScreenResolution  \
# 458  Microsoft  Surface Laptop  Ultrabook    13.5  Touchscreen 2256x1504
# 245       Dell   Inspiron 5570   Notebook    15.6      Full HD 1920x1080
#
#                             Cpu  Ram                Memory  \
# 458  Intel Core i7 7660U 2.5GHz  8GB             256GB SSD
# 245  Intel Core i7 8550U 1.8GHz  8GB  128GB SSD +  2TB HDD
#
#                               Gpu         OpSys  Weight  Price_euros   Price
# 458  Intel Iris Plus Graphics 640  Windows 10 S  1.25kg       1799.0  172200
# 245                AMD Radeon 530    Windows 10   2.2kg        985.0   94284

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample(2)
# Out:
#     Company         Product     TypeName  Inches   ScreenResolution  \
# 93     Dell   Inspiron 7577       Gaming    15.6  Full HD 1920x1080
# 447    Dell  Precision 3520  Workstation    15.6  Full HD 1920x1080
#
#                              Cpu  Ram                         Memory  \
# 93   Intel Core i5 7300HQ 2.5GHz  8GB                      256GB SSD
# 447  Intel Xeon E3-1505M V6 3GHz  8GB  64GB Flash Storage +  1TB HDD
#
#                          Gpu       OpSys  Weight   Price
# 93   Nvidia GeForce GTX 1060  Windows 10  2.65kg  114385
# 447       Nvidia Quadro M620  Windows 10  2.23kg  190770

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
51/1275
# Out:
# 0.04

# %%
# Removing these 4% of data, from companies which have less than 20 products

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
print(df.groupby('Company')['Company'].transform('count'))
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
df=df[df.groupby('Company')['Company'].transform('count')>20]

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['Company'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
sorted_company_list=df.groupby('Company')['Price'].mean().sort_values(ascending=False)
sorted_company_list
# Out:
# Company
# MSI        165491.055556
# Apple      149725.190476
# Toshiba    121355.000000
# Dell       114789.773196
# Asus       107572.947368
# Lenovo     104704.397924
# HP         103407.656716
# Acer        60635.198020
# Name: Price, dtype: float64

# %%
sorted_company_list.index
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sns.barplot(x=df['Company'],y=df['Price'],order=sorted_company_list.index,errorbar=None)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
print(df['Product'].value_counts())
# Out:
# Product
# XPS 13                30
# Inspiron 3567         25
# 250 G6                21
# Vostro 3568           19
# Legion Y520-15IKBN    19
#                       ..
# Portege X30-D-10L      1
# Zenbook UX390UA        1
# Portege X30-D-10J      1
# Latitude E5470         1
# VivoBook E12           1
# Name: count, Length: 589, dtype: int64

# %%
# if the number of categories is more than 20, we will render that column non-meaningful for our analysis

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# <ipython-input-37-4bcf6fa0a033>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#     Company TypeName  Inches   ScreenResolution                          Cpu  \
# 655    Dell   Gaming    15.6  Full HD 1920x1080  Intel Core i7 7820HK 2.9GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 655  16GB  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  3.49kg
#
#       Price
# 655  269332

# %%
# TypeName

# %%
print(df['TypeName'].value_counts())
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=45)
plt.show()

# %%
sorted_type_list=df.groupby('TypeName')['Price'].mean().sort_values(ascending=False)
print(sorted_type_list)
# Out:
# TypeName
# Workstation           218275.931034
# Gaming                160014.125000
# Ultrabook             148385.766082
# 2 in 1 Convertible    124385.157895
# Notebook               76183.475291
# Netbook                66215.636364
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],order=sorted_type_list.index,errorbar=None,palette='Reds',hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()

# %%
palette=sns.color_palette('Reds',len(sorted_type_list))[::-1]
color_dict=dict(zip(sorted_type_list.index,palette))

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],order=sorted_type_list.index,errorbar=None,palette=color_dict,hue=df['TypeName'])
plt.xticks(rotation=45)
plt.show()

# %%
print(df['Inches'].value_counts())
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.displot(df['Inches'],kde=True)

# %%
sns.kdeplot(df['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# ...

# %%
# df['X_res']
# df['Y_res']
# df['Ips']
# df['Touchscreen']

# %%
a="IPS Panel Touchscreen / 4K Ultra HD 3840x2160"
a.split()
# Out:
# ['IPS', 'Panel', 'Touchscreen', '/', '4K', 'Ultra', 'HD', '3840x2160']

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
(lambda a:a.split()[-1].split('x')[0])
# Out:
# <function __main__.<lambda>(a)>

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')
# Out:
# <ipython-input-58-40f364c1e3d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# <ipython-input-58-40f364c1e3d3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[1]).astype('int')

# %%
a
# Out:
# 'IPS Panel Touchscreen / 4K Ultra HD 3840x2160'

# %%
lambda a:[1 if 'IPS' in a else 0]
# Out:
# <function __main__.<lambda>(a)>

# %%
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)
# Out:
# <ipython-input-61-d12775f631bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if 'IPS' in a else 0)
# <ipython-input-61-d12775f631bd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if 'Touchscreen' in a else 0)

# %%
df.sample(4)
# Out:
#      Company     TypeName  Inches             ScreenResolution  \
# 1094      HP  Workstation    15.6  IPS Panel Full HD 1920x1080
# 29        HP     Notebook    17.3            Full HD 1920x1080
# 60      Dell    Ultrabook    14.0            Full HD 1920x1080
# 695     Dell     Notebook    15.6            Full HD 1920x1080
#
#                               Cpu  Ram                Memory  \
# 1094  Intel Core i7 6700HQ 2.6GHz  8GB             256GB SSD
# 29     Intel Core i5 8250U 1.6GHz  8GB               1TB HDD
# 60     Intel Core i5 8250U 1.6GHz  8GB             256GB SSD
# 695    Intel Core i5 8250U 1.6GHz  8GB  128GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 1094    Nvidia Quadro M1000M   Windows 7  2.59kg  213360   1920   1080    1
# 29      Nvidia GeForce 930MX  Windows 10   2.5kg   85765   1920   1080    0
# 60    Intel UHD Graphics 620  Windows 10   1.7kg   84138   1920   1080    0
# ...

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# <ipython-input-63-5a8c076be408>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample(4)
# Out:
#     Company   TypeName  Inches                                   Cpu   Ram  \
# 12    Apple  Ultrabook    15.4                  Intel Core i7 2.8GHz  16GB
# 195  Lenovo     Gaming    15.6           Intel Core i7 7700HQ 2.8GHz  16GB
# 775    Dell   Notebook    15.6            Intel Core i7 7500U 2.7GHz   8GB
# 356      HP   Notebook    15.6  Intel Pentium Quad Core N3710 1.6GHz   8GB
#
#                    Memory                      Gpu       OpSys  Weight  \
# 12              256GB SSD       AMD Radeon Pro 555       macOS  1.83kg
# 195  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1060  Windows 10   3.2kg
# 775               1TB HDD  Nvidia GeForce GT 940MX  Windows 10  1.98kg
# 356               2TB HDD    Intel HD Graphics 405  Windows 10  2.04kg
#
#       Price  X_res  Y_res  IPS  Touchscreen
# 12   233554   2880   1800    1            0
# 195  167414   1920   1080    1            0
# 775   91987   1920   1080    0            0
# 356   37235   1366    768    0            0

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              183
# Intel Core i7 7700HQ 2.8GHz             142
# Intel Core i7 7500U 2.7GHz              124
# Intel Core i5 8250U 1.6GHz               71
# Intel Core i7 8550U 1.8GHz               71
#                                        ...
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core M 6Y54 1.1GHz                  1
# AMD E-Series 9000 2.2GHz                  1
# Intel Core M 6Y30 0.9GHz                  1
# AMD A9-Series 9410 2.9GHz                 1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu_speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')
# Out:
# <ipython-input-66-7694fc30738f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace("GHz","")).astype('float')

# %%
a="Intel Core i5 7200U"
a
# Out:
# 'Intel Core i5 7200U'

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# <ipython-input-70-aa3ac16de377>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
print(len(df['Cpu'].value_counts()))
# Out:
# 36

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A6-Series A6-9220         2
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# Intel Atom x5-Z8350           1
# AMD Ryzen 1600                1
# ...

# %%
def fetch_processor_name(text):
    if "Core" in text:
        return text
    elif text.split()[0]=='Intel':
        return " ".join(text.split()[0:2])
    elif text.split()[0]=='AMD':
        if text[4]=="A":
            return "AMD A-Series"
        elif text[4]=="E":
            return "AMD E-Series"
        elif text[4]=="R":
            return "AMD Ryzen Series"
        elif text[4]=="F":
            return "AMD FX Series"
    else:
        return "Other Processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)
# Out:
# <ipython-input-74-8c092dd80c87>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A-Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E-Series          9
# Intel Atom            5
# AMD Ryzen Series      4
# Intel Xeon            4
# AMD FX Series         2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sorted_cpu_list=df.groupby('Cpu')['Price'].mean().sort_values(ascending=False)
print(sorted_cpu_list)
palette=sns.color_palette('Reds',len(sorted_cpu_list))[::-1]
color_dict=dict(zip(sorted_cpu_list.index,palette))
# Out:
# Cpu
# Intel Xeon          343060.500000
# AMD Ryzen Series    161335.750000
# Intel Core i7       151240.478702
# Intel Core M        135882.875000
# Intel Core i5        96865.690998
# AMD FX Series        81266.000000
# Intel Core i3        51962.417910
# AMD A-Series         47884.733333
# Intel Atom           41833.000000
# Intel Pentium        41689.866667
# Intel Celeron        30890.591549
# AMD E-Series         28800.888889
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['Cpu'],y=df['Price'],order=sorted_cpu_list.index,
            palette=color_dict,hue=df['Cpu'],errorbar=None)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.sample()
# Out:
#     Company TypeName  Inches            Cpu   Ram              Memory  \
# 744    Dell   Gaming    17.3  Intel Core i7  32GB  1TB SSD +  1TB HDD
#
#                           Gpu       OpSys  Weight   Price  X_res  Y_res  IPS  \
# 744  Nvidia GeForce GTX 1070M  Windows 10  4.42kg  343520   1920   1080    1
#
#      Touchscreen  Cpu_speed
# 744            0        2.8

# %%
print(df['Ram'].value_counts())
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda y:y.replace("GB","")).astype('int')
df['Weight']=df['Weight'].apply(lambda y:y.replace("kg","")).astype('float')
# Out:
# <ipython-input-82-48bea0c93f8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda y:y.replace("GB","")).astype('int')
# <ipython-input-82-48bea0c93f8b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda y:y.replace("kg","")).astype('float')

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram     Memory  \
# 420  Lenovo  Notebook    14.0  Intel Core i3    4  128GB SSD
#
#                        Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  \
# 420  Intel HD Graphics 620  Windows 10     1.7  57336   1920   1080    1
#
#      Touchscreen  Cpu_speed
# 420            0        2.7

# %%
df['Ram'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Ram'>

# %%
ram_list=df.groupby('Ram')['Price'].mean()
ram_list.index
color_p=sns.color_palette('Reds',len(ram_list))
color_p
# Out:
# [(0.9969242599000384, 0.8961937716262975, 0.8489042675893886),
#  (0.9913725490196079, 0.7913725490196079, 0.7082352941176471),
#  (0.9882352941176471, 0.6715417147251057, 0.5605382545174933),
#  (0.9874509803921568, 0.5411764705882353, 0.41568627450980394),
#  (0.9835755478662053, 0.4127950788158401, 0.28835063437139563),
#  (0.9466666666666667, 0.26823529411764707, 0.19607843137254902),
#  (0.8503344867358708, 0.14686658977316416, 0.13633217993079583),
#  (0.7364705882352941, 0.08, 0.10117647058823528),
#  (0.5946174548250673, 0.04613610149942329, 0.07558631295655516)]

# %%
sns.barplot(x=df['Ram'],y=df['Price'],palette=color_p,hue=df['Ram'],errorbar=None)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['IPS'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
print(df['Cpu_speed'].value_counts())
# Out:
# Cpu_speed
# 2.50    274
# 2.80    160
# 2.70    156
# 1.60    122
# 2.00     85
# 2.30     84
# 1.80     76
# 2.60     74
# 2.40     50
# 1.10     47
# 3.00     19
# 2.90     17
# 1.20     13
# 2.20     10
# 1.50     10
# 1.30      5
# 3.60      5
# 1.44      5
# 3.10      3
# 2.10      3
# 1.90      2
# 0.90      2
# 1.00      1
# 3.20      1
# Name: count, dtype: int64

# %%
sns.displot(df['Cpu_speed'],kde=True)

# %%
sns.scatterplot(x=df['Cpu_speed'],y=df['Price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Cpu_speed', ylabel='Price'>

# %%
sns.scatterplot(x=df['Cpu_speed'],y=df['Price'],hue=df['Cpu'])
plt.legend(loc='upper right',bbox_to_anchor=(1.5,1))

# %%
sns.displot(df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'],hue=(df['TypeName']=='Gaming'))
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df_g=df[df['TypeName']=='Gaming']

# %%
sns.scatterplot(x=df_g['Weight'],y=df_g['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'],hue=df['Inches'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'],hue=df['TypeName'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
import plotly.express as px
px.scatter(x=df['Weight'],y=df['Price'],color=df['TypeName'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram   Memory  \
# 854      HP  Notebook    15.6  Intel Core i7    8  1TB HDD
#
#                       Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  \
# 854  Nvidia GeForce 930MX  Windows 10    2.04  86148   1920   1080    0
#
#      Touchscreen  Cpu_speed
# 854            0        2.7

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# AMD Radeon R5 M315           1
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:" ".join(x.split()[0:2]))
# Out:
# <ipython-input-105-2666f22119d7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Nvidia GTX          1
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def gpu_names(text):
    if text=="Intel Graphics":
        return "Intel HD"
    elif text=="AMD R17M-M1-70" or text=="AMD R4":
        return "AMD Radeon"
    elif text=="Nvidia GTX":
        return "Nvidia GeForce"
    else:
        return text

# %%
df['Gpu']=df['Gpu'].apply(gpu_names)
# Out:
# <ipython-input-108-1526e45c92c6>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD          587
# Nvidia GeForce    354
# AMD Radeon        168
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Gpu'>

# %%
sorted_gpu_list=df.groupby('Gpu')['Price'].mean().sort_values(ascending=False)
print(sorted_gpu_list)
palette=sns.color_palette('Reds',len(sorted_gpu_list))[::-1]
color_dict=dict(zip(sorted_gpu_list.index,palette))
# Out:
# Gpu
# Nvidia Quadro     235328.483871
# Intel Iris        165480.090909
# AMD FirePro       156712.800000
# Nvidia GeForce    131904.392655
# Intel UHD         115416.044118
# Intel HD           94231.223169
# AMD Radeon         71443.297619
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],errorbar=None,
            order=sorted_gpu_list.index,palette=color_dict,hue=df['Gpu'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#    Company  TypeName  Inches            Cpu  Ram   Memory             Gpu  \
# 29      HP  Notebook    17.3  Intel Core i5    8  1TB HDD  Nvidia GeForce
#
#          OpSys  Weight  Price  X_res  Y_res  IPS  Touchscreen  Cpu_speed
# 29  Windows 10     2.5  85765   1920   1080    0            0        1.6

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Windows 10 S       2
# Android            2
# Name: count, dtype: int64

# %%
def fetch_os_name(text):
    if text=="Windows 10 S":
        return "Windows 10"
    elif text=="Mac OS X" or text=="macOS":
        return "Mac OS"
    elif text=="Chrome OS" or text=="Linux" or text=="Android":
        return "Linux/Others"
    else:
        return text

# %%
df['OpSys']=df['OpSys'].apply(fetch_os_name)
# Out:
# <ipython-input-116-21b8552f1324>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1013
# Linux/Others      82
# No OS             63
# Windows 7         45
# Mac OS            21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='OpSys'>

# %%
sorted_os_list=df.groupby('OpSys')['Price'].mean().sort_values(ascending=False)
print(sorted_os_list)
palette=sns.color_palette('Reds',len(sorted_os_list))[::-1]
color_dict=dict(zip(sorted_os_list.index,palette))
# Out:
# OpSys
# Windows 7       161446.177778
# Mac OS          149725.190476
# Windows 10      112125.036525
# Linux/Others     53605.597561
# No OS            53492.825397
# Name: Price, dtype: float64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],errorbar=None,order=sorted_os_list.index,
            palette=color_dict,hue=df['OpSys'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company            TypeName  Inches            Cpu  Ram     Memory  \
# 676    Acer  2 in 1 Convertible    13.3  Intel Core i5    8  256GB SSD
#
#            Gpu       OpSys  Weight  Price  X_res  Y_res  IPS  Touchscreen  \
# 676  Intel UHD  Windows 10     1.6  95624   1920   1080    1            1
#
#      Cpu_speed
# 676        1.6

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# ...

# %%
# HDD
# SSD
# Flash Storage
# Hybrid

# %%
df['Memory']=df['Memory'].astype('str').replace("\.0","",regex=True)
# Out:
# <ipython-input-124-26fa70b28114>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['Memory']=df['Memory'].str.replace("GB","")
df['Memory']=df['Memory'].str.replace("TB","000")
# Out:
# <ipython-input-125-8ed97e19a654>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-125-8ed97e19a654>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 32 SSD                            2
# 256 SSD +  500 HDD                2
# 1000 SSD +  1000 HDD              2
# ...

# %%
new=df['Memory'].str.split('+',expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]
# Out:
# <ipython-input-127-880982f97623>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-127-880982f97623>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-127-880982f97623>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash']=df['first'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-128-4978ec531ce1>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-128-4978ec531ce1>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-128-4978ec531ce1>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['first']=df['first'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-129-043ccd27c636>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['second'].fillna("0",inplace=True)
df['second']=df['second'].str.strip()
# Out:
# <ipython-input-130-35a0e6b0e560>:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# <ipython-input-130-35a0e6b0e560>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-130-35a0e6b0e560>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# <ipython-input-131-4e7f321ddd0d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-4e7f321ddd0d>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-131-4e7f321ddd0d>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['second']=df['second'].str.replace(r'\D','',regex=True)
# Out:
# <ipython-input-132-7e4a144e1deb>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')
# Out:
# <ipython-input-133-985d4fe1ffcd>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-133-985d4fe1ffcd>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash']+df['second']*df['Layer2Flash']
# Out:
# <ipython-input-134-ab0518cd5d0c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-134-ab0518cd5d0c>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-134-ab0518cd5d0c>:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash'],inplace=True)
# Out:
# <ipython-input-135-181153d3af2d>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# <ipython-input-136-8cab1fd6fcc0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.sample(4)
# Out:
#      Company            TypeName  Inches            Cpu  Ram             Gpu  \
# 299   Lenovo            Notebook    15.6  Intel Core i5    8  Nvidia GeForce
# 1131  Lenovo  2 in 1 Convertible    14.0  Intel Core i5    8        Intel HD
# 1069  Lenovo              Gaming    17.3  Intel Core i7   16  Nvidia GeForce
# 41      Asus            Notebook    15.6  Intel Core i5    8  Nvidia GeForce
#
#              OpSys  Weight   Price  X_res  Y_res  IPS  Touchscreen  Cpu_speed  \
# 299     Windows 10    2.30   78395   1920   1080    0            0        2.5
# 1131    Windows 10    1.36  156694   2560   1440    1            1        2.3
# 1069    Windows 10    4.60  263229   1920   1080    1            0        2.7
# 41    Linux/Others    2.30   50061   1366    768    0            0        2.5
#
#        HDD  SSD  Hybrid  Flash_Storage
# 299   1000  128       0              0
# 1131     0  256       0              0
# 1069     0  256    1000              0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches         1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram            0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight         0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price          0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res         -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res         -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# IPS           -0.104090  0.223322  0.038753  0.289225  0.283969  0.294360
# Touchscreen   -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# Cpu_speed      0.296510  0.356482  0.313267  0.422535  0.187056  0.178539
# HDD            0.525077  0.106175  0.503765 -0.093770 -0.109044 -0.115936
# SSD           -0.114322  0.589636 -0.063144  0.654751  0.523882  0.518090
# Hybrid         0.050989  0.052774  0.105129  0.025523 -0.000097 -0.000967
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='summer')
# Out:
# <Axes: >

# %%
print(df.corr(numeric_only=True)['Price'])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# Price            1.000000
# X_res            0.553707
# Y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed        0.422535
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# Name: Price, dtype: float64

# %%
# ppi: pixel density

# %%
df['ppi']=round((df['X_res']**2+df['Y_res']**2)**0.5/df['Inches']).astype('int')
# Out:
# <ipython-input-142-a0d3940d5da9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df.corr(numeric_only=True)['Price'])
# Out:
# Inches           0.055330
# Ram              0.726639
# Weight           0.212038
# Price            1.000000
# X_res            0.553707
# Y_res            0.552964
# IPS              0.289225
# Touchscreen      0.161443
# Cpu_speed        0.422535
# HDD             -0.093770
# SSD              0.654751
# Hybrid           0.025523
# Flash_Storage   -0.023384
# ppi              0.483821
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)
# Out:
# <ipython-input-144-3e9aaf9787dd>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
# Out:
# <ipython-input-145-06b8a3d14dd7>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df.corr(numeric_only=True)['Price'])
# Out:
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# IPS            0.289225
# Touchscreen    0.161443
# Cpu_speed      0.422535
# HDD           -0.093770
# SSD            0.654751
# ppi            0.483821
# Name: Price, dtype: float64

# %%
df.sample(3)
# Out:
#      Company            TypeName            Cpu  Ram             Gpu  \
# 590     Asus              Gaming  Intel Core i7    8  Nvidia GeForce
# 49    Lenovo  2 in 1 Convertible     Intel Atom    4        Intel HD
# 1066      HP           Ultrabook  Intel Core i7    8        Intel HD
#
#              OpSys  Weight   Price  IPS  Touchscreen  Cpu_speed   HDD  SSD  \
# 590     Windows 10    3.00  111801    0            0       2.80  1000  128
# 49    Linux/Others    0.69   30535    1            1       1.44     0    0
# 1066    Windows 10    1.16  188473    0            0       2.50     0  512
#
#       ppi
# 590   127
# 49    224
# 1066  166

# %%
df['SSD'].value_counts()
# Out:
# SSD
# 256     479
# 0       425
# 128     166
# 512     125
# 1000     14
# 180       5
# 16        3
# 32        2
# 64        1
# 1024      1
# 768       1
# 240       1
# 8         1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['SSD'],y=df['Price'])
# Out:
# <Axes: xlabel='SSD', ylabel='Price'>

# %%
sns.displot(df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df.sample()
# Out:
#      Company  TypeName            Cpu  Ram       Gpu       OpSys  Weight  \
# 1181    Dell  Notebook  Intel Core i3    8  Intel HD  Windows 10     2.3
#
#       Price  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# 1181  44894    0            1        2.4  1000    0  100

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
print(df['Price'].describe())
# Out:
# count      1224.000000
# mean     107645.160131
# std       64118.113675
# min       16655.000000
# 25%       58666.750000
# 50%       93710.000000
# 75%      141426.000000
# max      468932.000000
# Name: Price, dtype: float64

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df.to_csv('laptop_data_cleaned.csv',index=False)

# %%
X=df.drop(columns=['Price'])
y=df['Price']

# %%
X.shape
# Out:
# (1224, 13)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=32)

# %%
X_train.shape,X_test.shape
# Out:
# ((1040, 13), (184, 13))

# %%
1040/1224
# Out:
# 0.8496732026143791

# %%
X_train
# Out:
#      Company            TypeName            Cpu  Ram             Gpu  \
# 460   Lenovo            Notebook  Intel Core i5    8        Intel HD
# 1161    Asus            Notebook  Intel Core i7   16  Nvidia GeForce
# 1192    Dell  2 in 1 Convertible  Intel Core i7   16  Nvidia GeForce
# 330     Dell            Notebook  Intel Core i5    8  Nvidia GeForce
# 1220  Lenovo  2 in 1 Convertible  Intel Core i7   16        Intel HD
# ...      ...                 ...            ...  ...             ...
# 1095      HP  2 in 1 Convertible  Intel Core i7    8        Intel HD
# 252   Lenovo            Notebook  Intel Core i3    4        Intel HD
# 88      Asus              Gaming  AMD FX Series    8      AMD Radeon
# 892      MSI              Gaming  Intel Core i7    8  Nvidia GeForce
# 727     Acer            Notebook  Intel Core i5    4        Intel HD
#
#            OpSys  Weight  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# ...

# %%
y_train
# Out:
# 460     130562
# 1161    167414
# 1192    172200
# 330     109384
# 1220    143484
#          ...
# 1095    172200
# 252      42500
# 88       66908
# 892     114768
# 727      57336
# Name: Price, Length: 1040, dtype: int64

# %%
print(X_train.dtypes)
# Out:
# Company         object
# TypeName        object
# Cpu             object
# Ram              int64
# Gpu             object
# OpSys           object
# Weight         float64
# IPS              int64
# Touchscreen      int64
# Cpu_speed      float64
# HDD              int64
# SSD              int64
# ppi              int64
# dtype: object

# %%
# Company, TypeName, Cpu, Gpu, OpSys

# %%
# Encoding: Process of converting non-numerical data to numerical data
# Label Encoding
# Ordinal Encoding  : Ordered Data/ordinal data
# One Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor

# %%
# step 1 : onehot encoding within column transformer
# step 2: linear regression
# step1 + step2 = pipeline

# %%
X_train.sample()
# Out:
#    Company   TypeName            Cpu  Ram         Gpu   OpSys  Weight  IPS  \
# 12   Apple  Ultrabook  Intel Core i7   16  AMD Radeon  Mac OS    1.83    1
#
#     Touchscreen  Cpu_speed  HDD  SSD  ppi
# 12            0        2.8    0  256  221

# %%
# Linear Regression
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8056790702988444
# RMSE     :    25872.876102061397
# MAE      :    19382.282004089277

# %%
# X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=40,stratify=df['Cpu'])

# %%
X_train[X_train['Cpu']=='AMD FX Series']
# Out:
#     Company TypeName            Cpu  Ram         Gpu       OpSys  Weight  IPS  \
# 900  Lenovo   Gaming  AMD FX Series   16  AMD Radeon  Windows 10    2.50    1
# 88     Asus   Gaming  AMD FX Series    8  AMD Radeon  Windows 10    2.45    0
#
#      Touchscreen  Cpu_speed   HDD  SSD  ppi
# 900            0        2.1  1000  512  141
# 88             0        3.0  1000    0  141

# %%
X_test[X_test['Cpu']=='AMD FX Series']
# Out:
# Empty DataFrame
# Columns: [Company, TypeName, Cpu, Ram, Gpu, OpSys, Weight, IPS, Touchscreen, Cpu_speed, HDD, SSD, ppi]
# Index: []

# %%
df[df['Cpu']=='AMD FX Series']
# Out:
#     Company TypeName            Cpu  Ram         Gpu       OpSys  Weight  \
# 88     Asus   Gaming  AMD FX Series    8  AMD Radeon  Windows 10    2.45
# 900  Lenovo   Gaming  AMD FX Series   16  AMD Radeon  Windows 10    2.50
#
#      Price  IPS  Touchscreen  Cpu_speed   HDD  SSD  ppi
# 88   66908    0            0        3.0  1000    0  141
# 900  95624    1            0        2.1  1000  512  141

# %%
# y=m1x1+m2x2+m3x3+....+c
# Price= 0.5*cpu+10000*ram+0*ssd+0.4*ppi+0.03*company+..

# Some features which are irrelevant or noisy
# Features are highly correlated (multicollinearity)
# Too many features
# Overfitting

# %%
# Regularization
# L2 Regularization(Ridge Regression)
        # Penalize large coefficients
        # The model still uses all the features, but keeps their weights small
        # Generally works when there are many small/medium useful features
# L1 Regularization(Lasso Regression)
        # It can actually set some coefficients to zero, if the feature is not helping engough
# alpha

# %%
# Ridge Regression(L2 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Ridge()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8059480701827569
# RMSE     :    25854.96189443341
# MAE      :    19393.4336182393

# %%
# Lasso Regression(L1 regularization)
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=Lasso()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8057185203459725
# RMSE     :    25870.24967887573
# MAE      :    19377.977790173365

# %%
# KNN Regressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=KNeighborsRegressor(n_neighbors=4)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.687348220024937
# RMSE     :    32818.246428379316
# MAE      :    22068.375

# %%
# Support Vector Regressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=SVR(C=100000000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.7366202991676197
# RMSE     :    30121.463504365594
# MAE      :    20694.25359495531

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.7809949501651605
# RMSE     :    27467.04781060352
# MAE      :    19609.318181015784

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=AdaBoostRegressor(n_estimators=5)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.7115211281931892
# RMSE     :    31524.04396007929
# MAE      :    26104.935283609444

# %%
# RandomForestRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8509651175410824
# RMSE     :    22658.381444409264
# MAE      :    16283.714204063146

# %%
# XGBRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=XGBRegressor(max_depth=3,n_estimators=100)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8747457265853882
# RMSE     :    20772.13671875
# MAE      :    15947.0634765625

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
step2=GradientBoostingRegressor(max_depth=5)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 Score :   ",r2_score(y_test,y_pred))
print("RMSE     :   ",root_mean_squared_error(y_test,y_pred))
print("MAE      :   ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 Score :    0.8734708244469996
# RMSE     :    20877.584884029486
# MAE      :    15727.558642267406

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
# Streamlit

# %%
# !pip install streamlit --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.7 MB/s eta 0:00:00

# %%
# %%writefile abc.txt
# This is my text file
# I am adding another line of text here.
# And another as well
# Out:
# Overwriting abc.txt

# %%
# %%writefile app.py
import streamlit as st
import numpy as np
import pickle
lr_model=pickle.load(open('pipe.pkl','rb'))
df=pickle.load(open('df.pkl','rb'))

st.title("Laptop Price Predictor App")
st.write("This app is created using the data taken from kaggle website.")
st.write("The prediction here is based on the data available, hence might not align perfectly with the real-life data.")

company=st.selectbox("Laptop Manufacturer",df['Company'].unique(),index=4)
typename=st.selectbox("Type of Laptop",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
cpu_speed=st.slider("CPU Clock Speed",min_value=0.8,max_value=4.0,step=0.1,value=2.5)
ram=st.radio("Amount of RAM on the system",[4,6,8,12,16,24,32,64,128],index=2,horizontal=True)
gpu=st.selectbox("Graphics Card on the system",df['Gpu'].unique(),index=1)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight of the laptop(in kg)",min_value=0.6,max_value=5.0,step=0.2,value=2.0)
ips=st.selectbox("Does the laptop display have IPS Panel?",["Yes",'No'],index=1)
touchscreen=st.selectbox("Does the laptop have a touchscreen?",["Yes",'No'],index=1)
ssd=st.selectbox("What is the SSD storage on the system? If system has HDD storage only, select 0",
                 [0,128,256,512,1024],index=3)
hdd=st.selectbox("What is the HDD storage on the system? If system has SSD only, then select 0",
                 [0,128,256,512,1024,2048],index=0)
screen_size=st.slider("Screen size(in inches, measured diagonally)",min_value=10.0,max_value=18.5,step=0.1,value=15.6)
screen_resolution=st.selectbox("Screen Resolution(in horizontal x vertical pixels)",
                               ["2560x1600","1440x900","1920x1080","2880x1800","1366x768","2304x1440",
                                "3200x1800","1920x1200","2256x1504","3840x2160","2160x1440","2560x1440",
                                "1600x900","2736x1824","2400x1600"],index=2)
if st.button("PREDICT PRICE"):
    X_res=int(screen_resolution.split('x')[0])
    Y_res=int(screen_resolution.split('x')[1])
    ppi=(X_res**2+Y_res**2)**0.5/screen_size
    if ips=='Yes':
        ips=1
    else:
        ips=0
    if touchscreen=='Yes':
        touchscreen=1
    else:
        touchscreen=0
    query=np.array([[company,typename,cpu,ram,gpu,os,weight,ips,touchscreen,cpu_speed,hdd,ssd,ppi]])
    op=lr_model.predict(query)
    st.subheader("The predicted price of the laptop with the above mentioned specification is ₹"+ str(int(round(op[0],-2))))
# Out:
# Overwriting app.py

# %%
X_train.sample()
# Out:
#    Company   TypeName            Cpu  Ram         Gpu   OpSys  Weight  IPS  \
# 44   Apple  Ultrabook  Intel Core i5    8  Intel Iris  Mac OS    1.37    1
#
#     Touchscreen  Cpu_speed  HDD  SSD  ppi
# 44            0        2.0    0  256  227

# %%
print(df['Weight'].describe())
# Out:
# count    1224.000000
# mean        2.063204
# std         0.663863
# min         0.690000
# 25%         1.597500
# 50%         2.060000
# 75%         2.320000
# max         4.700000
# Name: Weight, dtype: float64

# %%
df['OpSys'].unique()
# Out:
# array(['Mac OS', 'No OS', 'Windows 10', 'Linux/Others', 'Windows 7'],
#       dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# ⠙
# ...
#
# ⠹⠸⠼
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.106.200.79:8501
#
# ⠴⠦your url is: https://busy-rooms-speak.loca.lt
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
#   Stopping...
# ^C

# %%
price=[109890.08408288]

# %%
print(int(round(price[0],-2)))
# Out:
# 109900

# %%
print("The predicted price of the laptop with the above mentioned specification is ₹"+ str(int(round(price[0],-2))))
# Out:
# The predicted price of the laptop with the above mentioned specification is ₹109900

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.6.1'
